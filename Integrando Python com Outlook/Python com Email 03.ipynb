# %% [markdown]
# # Integração Python com Outlook
#
# ### Funciona para qualquer e-mail: corporativo, gmail, hotmail, etc.
#
# - Passo 1: Importar win32 e inicializar o outlook

# %%
import win32com.client as win32
outlook = win32.client.Dispatch('outlook.application')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\macha\workspace\github\Python-Impressionador-Hashtag\Integrando Python com Outlook\Python com Email 03.ipynb Célula 2 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/macha/workspace/github/Python-Impressionador-Hashtag/Integrando%20Python%20com%20Outlook/Python%20com%20Email%2003.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import win32com.client as win32
# ----> <a href='vscode-notebook-cell:/c%3A/Users/macha/workspace/github/Python-Impressionador-Hashtag/Integrando%20Python%20com%20Outlook/Python%20com%20Email%2003.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> outlook = win32.client.Dispatch('outlook.application')
#
# AttributeError: module 'win32com.client' has no attribute 'client'

# %% [markdown]
# - Passo 2: Escrever o e-mail e disparar

# %%
mail = outlook.CreateItem(0)
mail.To = 'machado.vanessa32@hotmail.com'
mail.CC = 'vanessaestudoaws@gmail.com'
mail.BCC = 'machado.vanessa32@gmail.com'
mail.Subject = 'Email vindo do Outlook'
mail.Body = 'Texto do E-mail'
#ou mail.HTMLBody = '<p>Corpo do Email em HTML</p>'

# Anexos (pode colocar quantos quiser):
# attachment  = r'C:\Users\joaop\Google Drive\Python Impressionador\Financeiro.xlsx'
# mail.Attachments.Add(attachment)

mail.Send()
